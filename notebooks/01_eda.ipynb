# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/ayana/PycharmProjects/aqi-predictor/data/raw/all_cities_historical.csv")
df["date"].max()
# Out:
# '2026-07-31 23:00:00+00:00'

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 349440 entries, 0 to 349439
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  349440 non-null  datetime64[us, UTC]
#  1   us_aqi                349440 non-null  float64
#  2   pm10                  349440 non-null  float64
#  3   pm2_5                 349440 non-null  float64
#  4   carbon_monoxide       349440 non-null  float64
#  5   nitrogen_dioxide      349440 non-null  float64
#  6   sulphur_dioxide       349440 non-null  float64
#  7   ozone                 349440 non-null  float64
#  8   temperature_2m        349440 non-null  float64
#  9   wind_speed_10m        349440 non-null  float64
#  10  wind_direction_10m    349440 non-null  float64
#  11  relative_humidity_2m  349440 non-null  float64
#  12  surface_pressure      349440 non-null  float64
#  13  precipitation         349440 non-null  float64
#  14  city                  349440 non-null  str
# dtypes: datetime64[us, UTC](1), float64(13), str(1)
# memory usage: 40.0 MB

# %%
df.loc["2023-06-01"]
df.groupby("hour")["us_aqi"].max()
# Out:
# hour
# 0     534.97920
# 1     528.77080
# 2     524.42500
# 3     519.45830
# 4     512.66660
# 5     504.40417
# 6     497.57080
# 7     493.88336
# 8     492.79584
# 9     492.56250
# 10    491.89996
# 11    489.84167
# 12    485.88336
# 13    470.55835
# 14    451.00415
# 15    436.87080
# 16    437.37500
# 17    435.20416
# 18    442.80414
# 19    473.76250
# 20    500.28748
# 21    520.15830
# 22    532.72920
# 23    537.53754
# Name: us_aqi, dtype: float64

# %%
monthly_2024 = df.loc["2024"]["us_aqi"].resample("ME").mean() #Monthly 2024 AQI Mean
monthly_2024
# Out:
# date
# 2024-01-31 00:00:00+00:00    166.868002
# 2024-02-29 00:00:00+00:00    109.978248
# 2024-03-31 00:00:00+00:00     95.243533
# 2024-04-30 00:00:00+00:00     84.408725
# 2024-05-31 00:00:00+00:00     92.599980
# 2024-06-30 00:00:00+00:00    103.858560
# 2024-07-31 00:00:00+00:00    122.918197
# 2024-08-31 00:00:00+00:00     93.931967
# 2024-09-30 00:00:00+00:00    106.296073
# 2024-10-31 00:00:00+00:00    111.983387
# 2024-11-30 00:00:00+00:00    143.624428
# 2024-12-31 00:00:00+00:00    154.587010
# Freq: ME, Name: us_aqi, dtype: float64

# %%
all_month=df["us_aqi"].resample("ME").mean()
all_month
# Out:
# date
# 2022-08-31 00:00:00+00:00    100.408561
# 2022-09-30 00:00:00+00:00    120.660565
# 2022-10-31 00:00:00+00:00    128.027615
# 2022-11-30 00:00:00+00:00    135.819350
# 2022-12-31 00:00:00+00:00    144.507230
# 2023-01-31 00:00:00+00:00    150.084613
# 2023-02-28 00:00:00+00:00    130.072385
# 2023-03-31 00:00:00+00:00    110.082305
# 2023-04-30 00:00:00+00:00     92.847831
# 2023-05-31 00:00:00+00:00     95.075714
# 2023-06-30 00:00:00+00:00    104.352409
# 2023-07-31 00:00:00+00:00    110.273292
# 2023-08-31 00:00:00+00:00    115.986023
# 2023-09-30 00:00:00+00:00    102.655302
# 2023-10-31 00:00:00+00:00    105.298014
# 2023-11-30 00:00:00+00:00    127.223784
# 2023-12-31 00:00:00+00:00    133.172884
# 2024-01-31 00:00:00+00:00    166.868002
# 2024-02-29 00:00:00+00:00    109.978248
# 2024-03-31 00:00:00+00:00     95.243533
# 2024-04-30 00:00:00+00:00     84.408725
# 2024-05-31 00:00:00+00:00     92.599980
# 2024-06-30 00:00:00+00:00    103.858560
# 2024-07-31 00:00:00+00:00    122.918197
# 2024-08-31 00:00:00+00:00     93.931967
# 2024-09-30 00:00:00+00:00    106.296073
# 2024-10-31 00:00:00+00:00    111.983387
# 2024-11-30 00:00:00+00:00    143.624428
# 2024-12-31 00:00:00+00:00    154.587010
# 2025-01-31 00:00:00+00:00    157.288006
# 2025-02-28 00:00:00+00:00    117.411717
# 2025-03-31 00:00:00+00:00     97.709431
# 2025-04-30 00:00:00+00:00    101.998259
# 2025-05-31 00:00:00+00:00    123.402995
# 2025-06-30 00:00:00+00:00    119.473210
# 2025-07-31 00:00:00+00:00    117.331456
# 2025-08-31 00:00:00+00:00    108.930186
# 2025-09-30 00:00:00+00:00     99.392519
# 2025-10-31 00:00:00+00:00    119.247872
# 2025-11-30 00:00:00+00:00    142.375725
# 2025-12-31 00:00:00+00:00    158.449062
# 2026-01-31 00:00:00+00:00    164.025926
# 2026-02-28 00:00:00+00:00    127.314319
# 2026-03-31 00:00:00+00:00    102.734116
# 2026-04-30 00:00:00+00:00     91.543721
# 2026-05-31 00:00:00+00:00    111.450347
# 2026-06-30 00:00:00+00:00    118.645368
# 2026-07-31 00:00:00+00:00    124.001505
# Freq: ME, Name: us_aqi, dtype: float64

# %%
daily_avg = df["us_aqi"].resample("D").mean()
daily_avg.head(10)
# Out:
# date
# 2022-08-06 00:00:00+00:00     95.549770
# 2022-08-07 00:00:00+00:00    121.317004
# 2022-08-08 00:00:00+00:00    114.821842
# 2022-08-09 00:00:00+00:00    124.522588
# 2022-08-10 00:00:00+00:00    133.425604
# 2022-08-11 00:00:00+00:00    120.254474
# 2022-08-12 00:00:00+00:00     79.956508
# 2022-08-13 00:00:00+00:00    101.895590
# 2022-08-14 00:00:00+00:00    101.280500
# 2022-08-15 00:00:00+00:00     79.776185
# Freq: D, Name: us_aqi, dtype: float64

# %%
# %matplotlib inline

# %%
daily=df.loc["2026"]["us_aqi"].resample("D").mean()
daily
# Out:
# date
# 2026-01-01 00:00:00+00:00    151.791902
# 2026-01-02 00:00:00+00:00    170.548434
# 2026-01-03 00:00:00+00:00    162.972071
# 2026-01-04 00:00:00+00:00    172.825103
# 2026-01-05 00:00:00+00:00    184.648467
#                                 ...
# 2026-07-27 00:00:00+00:00    124.633799
# 2026-07-28 00:00:00+00:00    119.659075
# 2026-07-29 00:00:00+00:00    113.829353
# 2026-07-30 00:00:00+00:00    126.564272
# 2026-07-31 00:00:00+00:00    120.503701
# Freq: D, Name: us_aqi, Length: 212, dtype: float64

# %%
daily_avg.plot(figsize=(19, 10), title="Karachi Daily Average AQI")
# Out:
# <Axes: title={'center': 'Karachi Daily Average AQI'}, xlabel='date'>

# %%
one_day = df.loc["2026-07-29"]
one_day
# Out:
#                               us_aqi  pm10  pm2_5  carbon_monoxide  \
# date
# 2026-07-29 00:00:00+00:00  77.877360  42.3   19.8            136.0
# 2026-07-29 01:00:00+00:00  78.294030  41.1   19.4            181.0
# 2026-07-29 02:00:00+00:00  78.663530  42.7   19.6            241.0
# 2026-07-29 03:00:00+00:00  78.930820  52.4   22.9            278.0
# 2026-07-29 04:00:00+00:00  79.150940  58.9   25.1            268.0
# ...                              ...   ...    ...              ...
# 2026-07-29 19:00:00+00:00  96.666670  45.5   41.4            868.0
# 2026-07-29 20:00:00+00:00  95.911960  44.4   40.5            641.0
# 2026-07-29 21:00:00+00:00  95.369490  43.9   40.2            476.0
# 2026-07-29 22:00:00+00:00  94.952835  44.0   40.2            435.0
# 2026-07-29 23:00:00+00:00  94.654090  44.9   41.1            456.0
#
#                            nitrogen_dioxide  sulphur_dioxide  ozone  \
# date
# 2026-07-29 00:00:00+00:00               4.9              4.3   54.0
# 2026-07-29 01:00:00+00:00               6.2              4.5   52.0
# 2026-07-29 02:00:00+00:00               7.8              4.9   50.0
# 2026-07-29 03:00:00+00:00               8.7              5.2   52.0
# 2026-07-29 04:00:00+00:00               8.0              5.5   60.0
# ...                                     ...              ...    ...
# 2026-07-29 19:00:00+00:00              26.7              9.2   58.0
# 2026-07-29 20:00:00+00:00              25.7              8.5   55.0
# 2026-07-29 21:00:00+00:00              24.9              8.1   53.0
# 2026-07-29 22:00:00+00:00              24.6              8.0   50.0
# 2026-07-29 23:00:00+00:00              24.4              8.2   48.0
#
#                            temperature_2m  wind_speed_10m  wind_direction_10m  \
# date
# 2026-07-29 00:00:00+00:00           28.00       11.918120          244.983140
# 2026-07-29 01:00:00+00:00           27.95       12.409561          246.037500
# 2026-07-29 02:00:00+00:00           28.40       15.086748          250.484040
# 2026-07-29 03:00:00+00:00           29.30       16.520823          258.690100
# 2026-07-29 04:00:00+00:00           30.40       16.572712          261.253900
# ...                                   ...             ...                 ...
# 2026-07-29 19:00:00+00:00           28.15        5.247857           95.906044
# 2026-07-29 20:00:00+00:00           27.95        4.186693          115.463310
# 2026-07-29 21:00:00+00:00           27.65        3.572898          130.914290
# 2026-07-29 22:00:00+00:00           27.40        4.383286          109.179110
# 2026-07-29 23:00:00+00:00           27.30        5.232399           86.054890
#
#                            relative_humidity_2m  surface_pressure  \
# date
# 2026-07-29 00:00:00+00:00             90.773735         997.09500
# 2026-07-29 01:00:00+00:00             90.502846         997.49426
# 2026-07-29 02:00:00+00:00             87.383865         997.79517
# 2026-07-29 03:00:00+00:00             81.242200         998.09780
# 2026-07-29 04:00:00+00:00             74.914980         998.40060
# ...                                         ...               ...
# 2026-07-29 19:00:00+00:00             90.516220         973.24976
# 2026-07-29 20:00:00+00:00             90.770470         973.33070
# 2026-07-29 21:00:00+00:00             91.830650         973.11035
# 2026-07-29 22:00:00+00:00             92.634670         972.60240
# 2026-07-29 23:00:00+00:00             92.629395         972.39900
#
#                            precipitation        city  hour  month  day_of_week
# date
# 2026-07-29 00:00:00+00:00            0.0     Karachi     0      7            2
# 2026-07-29 01:00:00+00:00            0.0     Karachi     1      7            2
# 2026-07-29 02:00:00+00:00            0.0     Karachi     2      7            2
# 2026-07-29 03:00:00+00:00            0.0     Karachi     3      7            2
# 2026-07-29 04:00:00+00:00            0.0     Karachi     4      7            2
# ...                                  ...         ...   ...    ...          ...
# 2026-07-29 19:00:00+00:00            0.0  Gujranwala    19      7            2
# 2026-07-29 20:00:00+00:00            0.0  Gujranwala    20      7            2
# 2026-07-29 21:00:00+00:00            0.0  Gujranwala    21      7            2
# 2026-07-29 22:00:00+00:00            0.0  Gujranwala    22      7            2
# 2026-07-29 23:00:00+00:00            0.0  Gujranwala    23      7            2
#
# [240 rows x 17 columns]

# %%
# %matplotlib inline

# %%
daily=df["us_aqi"].resample("D").mean()
daily
# Out:
# date
# 2022-08-06 00:00:00+00:00     95.549770
# 2022-08-07 00:00:00+00:00    121.317004
# 2022-08-08 00:00:00+00:00    114.821842
# 2022-08-09 00:00:00+00:00    124.522588
# 2022-08-10 00:00:00+00:00    133.425604
#                                 ...
# 2026-07-27 00:00:00+00:00    124.633799
# 2026-07-28 00:00:00+00:00    119.659075
# 2026-07-29 00:00:00+00:00    113.829353
# 2026-07-30 00:00:00+00:00    126.564272
# 2026-07-31 00:00:00+00:00    120.503701
# Freq: D, Name: us_aqi, Length: 1456, dtype: float64

# %%
daily.plot(figsize=(20,4),title="Karachi Daily Average AQI")
# Out:
# <Axes: title={'center': 'Karachi Daily Average AQI'}, xlabel='date'>

# %%
monthly_by_year=df["us_aqi"].resample("ME").mean()
monthly_by_year
# Out:
# date
# 2022-08-31 00:00:00+00:00    100.408561
# 2022-09-30 00:00:00+00:00    120.660565
# 2022-10-31 00:00:00+00:00    128.027615
# 2022-11-30 00:00:00+00:00    135.819350
# 2022-12-31 00:00:00+00:00    144.507230
# 2023-01-31 00:00:00+00:00    150.084613
# 2023-02-28 00:00:00+00:00    130.072385
# 2023-03-31 00:00:00+00:00    110.082305
# 2023-04-30 00:00:00+00:00     92.847831
# 2023-05-31 00:00:00+00:00     95.075714
# 2023-06-30 00:00:00+00:00    104.352409
# 2023-07-31 00:00:00+00:00    110.273292
# 2023-08-31 00:00:00+00:00    115.986023
# 2023-09-30 00:00:00+00:00    102.655302
# 2023-10-31 00:00:00+00:00    105.298014
# 2023-11-30 00:00:00+00:00    127.223784
# 2023-12-31 00:00:00+00:00    133.172884
# 2024-01-31 00:00:00+00:00    166.868002
# 2024-02-29 00:00:00+00:00    109.978248
# 2024-03-31 00:00:00+00:00     95.243533
# 2024-04-30 00:00:00+00:00     84.408725
# 2024-05-31 00:00:00+00:00     92.599980
# 2024-06-30 00:00:00+00:00    103.858560
# 2024-07-31 00:00:00+00:00    122.918197
# 2024-08-31 00:00:00+00:00     93.931967
# 2024-09-30 00:00:00+00:00    106.296073
# 2024-10-31 00:00:00+00:00    111.983387
# 2024-11-30 00:00:00+00:00    143.624428
# 2024-12-31 00:00:00+00:00    154.587010
# 2025-01-31 00:00:00+00:00    157.288006
# 2025-02-28 00:00:00+00:00    117.411717
# 2025-03-31 00:00:00+00:00     97.709431
# 2025-04-30 00:00:00+00:00    101.998259
# 2025-05-31 00:00:00+00:00    123.402995
# 2025-06-30 00:00:00+00:00    119.473210
# 2025-07-31 00:00:00+00:00    117.331456
# 2025-08-31 00:00:00+00:00    108.930186
# 2025-09-30 00:00:00+00:00     99.392519
# 2025-10-31 00:00:00+00:00    119.247872
# 2025-11-30 00:00:00+00:00    142.375725
# 2025-12-31 00:00:00+00:00    158.449062
# 2026-01-31 00:00:00+00:00    164.025926
# 2026-02-28 00:00:00+00:00    127.314319
# 2026-03-31 00:00:00+00:00    102.734116
# 2026-04-30 00:00:00+00:00     91.543721
# 2026-05-31 00:00:00+00:00    111.450347
# 2026-06-30 00:00:00+00:00    118.645368
# 2026-07-31 00:00:00+00:00    124.001505
# Freq: ME, Name: us_aqi, dtype: float64

# %%
monthly_by_year.plot(figsize=(20,4),title="Karachi Monthly YoY AQI")
# Out:
# <Axes: title={'center': 'Karachi Monthly YoY AQI'}, xlabel='date'>

# %%
monthly_overall = df.groupby(df.index.month)["us_aqi"].mean()
monthly_overall
# Out:
# date
# 1     159.566637
# 2     121.094911
# 3     101.442346
# 4      92.699634
# 5     105.632259
# 6     111.582387
# 7     118.631112
# 8     104.999294
# 9     107.251115
# 10    116.139222
# 11    137.260822
# 12    147.679047
# Name: us_aqi, dtype: float64

# %%
monthly_overall.plot(figsize=(20,4),title="Karachi Monthly Overall AQI")
# Out:
# <Axes: title={'center': 'Karachi Monthly Overall AQI'}, xlabel='date'>

# %%
import pandas as pd

df = pd.read_csv("../data/raw/all_cities_historical.csv")
df["date"] = pd.to_datetime(df["date"], utc=True)
df = df.set_index("date")

df["hour"] = df.index.hour
df["month"] = df.index.month
df["day_of_week"] = df.index.dayofweek

df.shape
# Out:
# (349440, 17)

# %%
df.isna().sum()  #Checking Missing Data or NULLS
# Out:
# us_aqi                  0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# temperature_2m          0
# wind_speed_10m          0
# wind_direction_10m      0
# relative_humidity_2m    0
# surface_pressure        0
# precipitation           0
# city                    0
# hour                    0
# month                   0
# day_of_week             0
# dtype: int64

# %%
df[df["wind_speed_10m"].isna()]
# Out:
# Empty DataFrame
# Columns: [us_aqi, pm10, pm2_5, carbon_monoxide, nitrogen_dioxide, sulphur_dioxide, ozone, temperature_2m, wind_speed_10m, wind_direction_10m, relative_humidity_2m, surface_pressure, precipitation, city, hour, month, day_of_week]
# Index: []

# %%
df.groupby("city")["us_aqi"].apply(lambda col: col.isna().sum())
# Out:
# city
# Faisalabad    0
# Gujranwala    0
# Hyderabad     0
# Islamabad     0
# Karachi       0
# Lahore        0
# Multan        0
# Peshawar      0
# Quetta        0
# Rawalpindi    0
# Name: us_aqi, dtype: int64

# %%
df["us_aqi"].describe()
# Out:
# count    349440.000000
# mean        118.764528
# std          46.852655
# min          11.827457
# 25%          82.389930
# 50%         109.395836
# 75%         151.732150
# max         537.537540
# Name: us_aqi, dtype: float64

# %%
df["us_aqi"].hist(bins=100, figsize=(15, 5)) # split the full range of AQI values into 100 buckets
# Out:
# <Axes: >

# %%
df.groupby("city")["us_aqi"].mean().sort_values(ascending=False).plot(kind="bar", figsize=(10, 4))# City Wise AQI Mean
# Out:
# <Axes: xlabel='city'>

# %%
Q1 = df["us_aqi"].quantile(0.25)
Q3 = df["us_aqi"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["us_aqi"] < lower_bound) | (df["us_aqi"] > upper_bound)] #outside the normal range
print(f"Number of outlier rows: {len(outliers)}")
print(f"Outlier bounds: {lower_bound:.1f} to {upper_bound:.1f}")
# Out:
# Number of outlier rows: 4643
# Outlier bounds: -21.6 to 255.7

# %%
df.boxplot(column="us_aqi", by="city", figsize=(12, 5), rot=45)

# %%
monthly = df.groupby(["city", "month"])["us_aqi"].mean().unstack(level=0)
monthly.plot(figsize=(14, 6), title="Monthly Average AQI by City")  #Season Wise Data
# Out:
# <Axes: title={'center': 'Monthly Average AQI by City'}, xlabel='month'>

# %%
numeric_cols = ["us_aqi", "pm10", "pm2_5", "carbon_monoxide", "nitrogen_dioxide",
                 "sulphur_dioxide", "ozone", "temperature_2m", "wind_speed_10m",
                 "wind_direction_10m", "relative_humidity_2m", "surface_pressure",
                 "precipitation"]

correlation_matrix = df[numeric_cols].corr()
correlation_matrix["us_aqi"].sort_values(ascending=False)
# Out:
# us_aqi                  1.000000
# pm2_5                   0.777366
# pm10                    0.604348
# carbon_monoxide         0.514441
# sulphur_dioxide         0.512509
# nitrogen_dioxide        0.346146
# surface_pressure        0.313054
# relative_humidity_2m    0.187481
# ozone                   0.045394
# precipitation          -0.030149
# wind_direction_10m     -0.101174
# temperature_2m         -0.158900
# wind_speed_10m         -0.268059
# Name: us_aqi, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(len(numeric_cols)), numeric_cols, rotation=90)
plt.yticks(range(len(numeric_cols)), numeric_cols)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()                                               # whole grid

# %% [markdown]
# ## EDA Findings
# 1.Any columns with meaningful missing data? Which, and roughly how much?
# Answer: No columns have any missing values — .isna().sum() returned 0 across all 349,200 rows for every column.
#
# 2.Which city has the worst average AQI? Which has the best?
# Answer: Faisalabad has the worst average AQI (156.7), narrowly ahead of Lahore (153.6) — though Lahore's boxplot shows more          dramatic outlier spikes. Quetta has the best average AQI (74.0), consistent with its tight, low boxplot.
#
# 3.What's the correlation between wind speed and AQI — and does that match what you'd physically expect?
# Answer: AQI correlations: wind speed = −0.268 (higher wind → lower AQI, matches physical expectation — wind disperses pollution). Relative humidity = +0.188 (higher humidity → slightly higher AQI, consistent with humid air promoting particle formation and often coinciding with stagnant, low-dispersion conditions). Both moderate, not extreme — a healthy sign the model has real physical signal to learn from, not a shortcut.
#
# 4.Does seasonality look the same across all 10 cities, or different?
# Answer: Seasonality follows the same overall shape in nearly every city — AQI peaks in December–January and dips in spring —         matching the winter smog pattern from Q5. The difference between cities is intensity, not timing:
#         Faisalabad/Gujranwala swing dramatically (Jan avg 233 vs. Apr avg ~115), while Quetta stays comparatively flat year-round (peaks mildly in July, not winter).
#
# 5.Did you find outliers that look like real events versus likely sensor errors?
# Answer: Outliers cluster heavily in winter (93% fall in Nov–Jan), matching Pakistan's documented smog season — a real seasonal pattern, not sensor error. The single highest spike (Lahore, 537.5 AQI, May 2025) coincides with elevated wind speed, more consistent with a dust storm event than trapped winter smog. No evidence of random/scattered sensor glitches.
